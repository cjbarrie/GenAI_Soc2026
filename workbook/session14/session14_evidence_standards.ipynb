# %% [markdown]
# # Session 14 — What standards of evidence should govern LLM-assisted sociology?
#
# **Research target:** Audit one project record from claim through target, evidence, failure mode, and replication record.
#
# This notebook follows **question → input → type → transformation → raw output → check → research meaning**. Before each code cell, predict what Python object will come out. After it runs, explain it without relying on syntax jargon.

# %% [markdown]
# ## Why the code is here
#
# **Course claim:** The strongest course outcome is not a more confident claim, but a claim whose scope matches its actual evidence.
#
# **Characteristic failure:** A project reports an LLM capability but never states the sociological inference, reference evidence, or boundary of the claim.
#
# The code is a deliberately small research algorithm. It is not evidence that an LLM is valid.

# %% [markdown]
# ## 1. Meet the input objects
#
# Read brackets first: `[]` marks a list; `{}` marks a dictionary; quotation marks mark a string. `type(...)` asks Python what kind of object a value is. The cell below uses no live model.

# %%
project = {"claim": "The model measures trust", "inferential_target": "meeting-level trust", "input": ["synthetic excerpt"], "transformation": "classification", "validation": None, "replication_record": {}}
print(type(project))
# Out:
# <class 'dict'>

# %% [markdown]
# ## 2. Name the algorithm before running it
#
# **Input names:** `project`. The trace below prints the exact value and Python type for every input before calling the function.
#
# **Operation:** `audit_project_claim`.
#
# **Output:** an inspectable Python object. Read the `return` line to identify its type and contents.
#
# **Check:** the explicit assertions in Section 5.
#
# **Research meaning, in four steps**
#
# 1. `required` is a visible checklist, not a hidden grading rule.
# 2. The list comprehension flags absent keys and empty values while retaining their declared order.
# 3. The conditional changes the revision advice depending on whether evidence is missing.
# 4. The output does not approve the claim; it tells the researcher what must be bounded or supplied.
#
# ### Read every line of Python
#
# 1. `def audit_project_claim(project):`
#    `def` creates a reusable function. The names inside parentheses are the input names; the colon starts its indented body.
# 2. `"""Check six required research-design fields and return missing names plus a revision prompt."""`
#    The triple-quoted text documents what the function promises to return; Python does not execute it as an instruction.
# 3. `required = [`
#    `=` evaluates the expression on the right, then gives that value the name `required`. It does not test equality.
# 4. `"claim",`
#    Read the brackets and function calls from the inside out; this line contributes one value or action to the surrounding block.
# 5. `"inferential_target",`
#    Read the brackets and function calls from the inside out; this line contributes one value or action to the surrounding block.
# 6. `"input",`
#    Read the brackets and function calls from the inside out; this line contributes one value or action to the surrounding block.
# 7. `"transformation",`
#    Read the brackets and function calls from the inside out; this line contributes one value or action to the surrounding block.
# 8. `"validation",`
#    Read the brackets and function calls from the inside out; this line contributes one value or action to the surrounding block.
# 9. `"replication_record",`
#    Read the brackets and function calls from the inside out; this line contributes one value or action to the surrounding block.
# 10. `]`
#    This closing bracket ends the collection or function call opened above.
# 11. `missing = [field for field in required if project.get(field) in (None, "", [], {})]`
#    This comprehension repeats the expression before `for` and stores the resulting collection under `missing`; read it as a compact loop.
# 12. `if missing:`
#    This is a Boolean test. Python runs the indented block only when the expression before the colon is `True`.
# 13. `revision = "Bound the claim until these fields are supplied: " + ", ".join(missing)`
#    `=` evaluates the expression on the right, then gives that value the name `revision`. It does not test equality.
# 14. `else:`
#    `else` handles the remaining cases for which the preceding test was `False`.
# 15. `revision = (`
#    `=` evaluates the expression on the right, then gives that value the name `revision`. It does not test equality.
# 16. `"State the population, setting, model/runtime, "`
#    Read the brackets and function calls from the inside out; this line contributes one value or action to the surrounding block.
# 17. `"and validation evidence directly in the claim."`
#    Read the brackets and function calls from the inside out; this line contributes one value or action to the surrounding block.
# 18. `)`
#    This closing bracket ends the collection or function call opened above.
# 19. `return {"missing": missing, "revision": revision}`
#    `return` ends the function and sends this value back to the line that called it.
#
# The numbered guide explains Python mechanics. The four-step walkthrough explains why those mechanics belong in this research design; neither substitutes for the other.

# %%
def audit_project_claim(project):
    """Check six required research-design fields and return missing names plus a revision prompt."""
    required = [
        "claim",
        "inferential_target",
        "input",
        "transformation",
        "validation",
        "replication_record",
    ]
    missing = [field for field in required if project.get(field) in (None, "", [], {})]
    if missing:
        revision = "Bound the claim until these fields are supplied: " + ", ".join(missing)
    else:
        revision = (
            "State the population, setting, model/runtime, "
            "and validation evidence directly in the claim."
        )
    return {"missing": missing, "revision": revision}

# %% [markdown]
# ### Pause and say it aloud
#
# Point to each argument in the function header. Say what value enters it, what type that value has, what changes inside the function, and what `return` sends back. If you cannot do that yet, reread the four numbered sentences before editing code.

# %% [markdown]
# ## 3. Run one trace
#
# The next cell creates tiny synthetic inputs and prints the complete returned object. Printing before summarizing makes unexpected fields and values visible.

# %%
project = {"claim": "The model measures trust", "inferential_target": "meeting-level trust", "input": ["synthetic excerpt"], "transformation": "classification", "validation": None, "replication_record": {}}
print("input project:", type(project).__name__, repr(project))
print(audit_project_claim(project))
# Out:
# input project: dict {'claim': 'The model measures trust', 'inferential_target': 'meeting-level trust', 'input': ['synthetic excerpt'], 'transformation': 'classification', 'validation': None, 'replication_record': {}}
# {'missing': ['validation', 'replication_record'], 'revision': 'Bound the claim until these fields are supplied: validation, replication_record'}

# %% [markdown]
# ## 4. Connect the output to the research question
#
# A correct Python result means the declared transformation ran. It does **not** establish construct validity, representativeness, causality, emergence, or reproducibility. Interpret the output beside the inferential target and failure mode above.

# %% [markdown]
# ## 5. Run executable checks
#
# An `assert` states an expectation. If the statement after `assert` is `True`, Python continues silently. If it is `False`, Python stops at that exact expectation. Read the left and right sides before running.

# %%
partial = {"claim": "The model measures trust", "inferential_target": "meeting-level trust", "input": ["synthetic excerpt"], "transformation": "classification", "validation": None, "replication_record": {}}
audit = audit_project_claim(partial)
assert audit["missing"] == ["validation", "replication_record"]
assert "validation" in audit["revision"]
complete = {**partial, "validation": {"human_reference": True}, "replication_record": {"model": "m1"}}
assert audit_project_claim(complete)["missing"] == []
print('All worked-example checks passed.')
# Out:
# All worked-example checks passed.

# %% [markdown]
# ## 6. Your completion task
#
# Open `assessments/weekly_coding/session14_task.py`. Return a missing-evidence checklist and a bounded revision prompt for one project claim. Submit: (1) your prediction, (2) working code, (3) passing checks plus an interpreted diagnostic, and (4) a 100–150 word connection to one required reading.

# %% [markdown]
# ## Optional extension
#
# Add one small synthetic case designed to trigger the characteristic failure named at the start of this notebook. Predict the returned object before running it. Then explain whether the current output makes the failure visible or whether the research record needs another field. This is optional and is not part of the completion mark.

# %% [markdown]
# ## Required readings speak to this code
#
# - [Course synthesis: revisit one earlier empirical claim](../literature/literature_audit.md)
#
# Write one sentence beginning: **This algorithm makes ___ visible, but the reading shows it cannot by itself establish ___.**

# %% [markdown]
# ## Oral-assessment rehearsal
#
# Choose four consecutive lines from the function. Explain every name and bracket, predict the returned value, then change one input and predict exactly what changes. Accurate plain language is better than unexplained technical vocabulary.

# %% [markdown]
# ## AI-use disclosure
#
# If a tool materially assisted you, record: tool/model; what you used it for; what you incorporated; and how you checked it. You remain responsible for every claim and line of code.
